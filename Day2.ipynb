# %% [markdown]
# <a href="https://colab.research.google.com/github/SamsonKinara/CDAV/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input

# %%
name=input("Enter your name")
# Out:
# Enter your name Cole

# %%
print(name)
# Out:
#  Cole

# %%
name=input("What is your name?")
favourite_food=input("What is your favourite food?")
favourite_sport=input("What is your favourite sport?")
# Out:
# What is your name?Jude
# What is your favourite food?Fries
# What is your favourite sport?Soccer

# %%
print(f"Hello {name}!")
print(f"You like {favourite_food}.")
print(f"Your favourite sport is {favourite_sport}.")
# Out:
# Hello Jude!
# You like Fries.
# Your favourite sport is Soccer.

# %%
print("Hello",name+"!")
# Out:
# Hello Jude!

# %% [markdown]
# Data Types

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type("Harry"))
# Out:
# <class 'str'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
is_raining=True

# %%
print(type(is_raining))
# Out:
# <class 'bool'>

# %%
type(is_raining)
# Out:
# bool

# %%
#|comment

# %%
print(6//7)
# Out:
# 0

# %%
print(7//3)
# Out:
# 2

# %%
print(7/3)
# Out:
# 2.3333333333333335

# %%
#type casting-changing a value from one datatype to another copamtible datatype,g int to gloat..float to int.
#use short form of datatype as a function
float(10)
# Out:
# 10.0

# %%
int(3.14)
# Out:
# 3

# %%
str(3.14)
# Out:
# '3.14'

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
float(x)
# Out:
# 10.0

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
print(x)
# Out:
# 10.0

# %%
#input values are always collected as strings
age=input("What is your age")
# Out:
# What is your age 16

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
#type cast to int
age=int(input("What is your age"))
# Out:
# What is your age17

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
body_temperature=float(input("What is your body temperature in degrees celcius?"))
# Out:
# What is your body temperature in degrees celcius?37

# %%
body_temperature=((body_temperature*1.8)+32)

# %%
print(body_temperature)
# Out:
# 98.60000000000001

# %%
body_temperature=float(input("What is your body temperature in degrees celcius?"))
body_temperature=((body_temperature*1.8)+32)
print(f"Your body temperature is {body_temperature} F")
# Out:
# What is your body temperature in degrees celcius?35
# Your body temperature is 95.0 F

# %%
#compressed to one line
print("Your body temperature in frnht is",float(input("What is your body temp in degrees celc?"))*1.8+35)
# Out:
# What is your body temp in degrees celc?35
# Your body temperature in frnht is 98.0

# %%
x=(float(input("x=")))
y=(float(input("y=")))
print ("Sum of x and y is",x+y)
print("Difference of x and y is",x-y)
print("Multiplication of x and y is",x*y)
print("x divided by y is",x/y)
print("Integer division of x by y is",x//y)
print("modulus is",x%y)
print("x power y is",x**y)
# Out:
# x=10
# y=5
# Sum of x and y is 15.0
# Difference of x and y is 5.0
# Multiplication of x and y is 50.0
# x divided by y is 2.0
# Integer division of x by y is 2.0
# modulus is 0.0
# x power y is 100000.0
