# %% [markdown]
# <a href="https://colab.research.google.com/github/SamsonKinara/CDAV/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TAX

# %%
meal_cost=float(input("Cost of meal ordered "))
tax_on_meal=float(0.16*meal_cost)
tip=float(0.18*meal_cost)
total=meal_cost+tax_on_meal+tip
print(f"Tax on meal {tax_on_meal:.2f} shillings")
print(f"Tip {tip:.2f}shillings")
print(f"Your grand total is {total:.2f} shillings")
# Out:
# Cost of meal ordered 300
# Tax on meal 48.00 shillings
# Tip 54.00shillings
# Your grand total is 402.00 shillings

# %% [markdown]
# Widgets and Gizmos

# %%
widget_amount=int(input("Number of Widgets "))
gizmo_amount=int(input("number of gizmos "))
total_widget_weight=widget_amount*75
total_gizmo_weight=gizmo_amount*112
total_weight=total_gizmo_weight+total_widget_weight
print(f"the total weight of your order is {total_weight} grams")
# Out:
# Number of Widgets 5
# number of gizmos 7
# the total weight of your order is 1159 grams

# %% [markdown]
# Sum Of Integers

# %%
n=int(input("n: "))
sum=((n*(n+1))/2)
print(f" The sum of the first n positive integers is {sum}")
# Out:
# n: 7
#  The sum of the first n positive integers is 28.0

# %%
is_raining = True
if is_raining :
  print("Netflix and Chill")
# Out:
# Netflix and Chill

# %%
is_raining= False
if not is_raining:
  print("We outside")
# Out:
# We outside

# %%
balance = 500
amnt = float(input("How much do you want to withdraw?"))
if  balance<amnt:
    print("Insufficient balance")
    print("Top up and try again,brokey.")
if  balance>amnt:
  print("Withdrawal successful")
# Out:
# How much do you want to withdraw?3333
# Insufficient balance
# Top up and try again,brokey

# %%
marks=int(input("Enter exam marks "))
if marks>=50:
  print("Congratulations,you passed!!")
if marks<50:
  print("Unfortunately,you did not meet the exam passmark.")
# Out:
# Enter exam marks 50
# Congratulations,you passed!!

# %%
is_raining=False
if is_raining:
  print("Netflix and Chill")
else:
  print("We outside")
# Out:
# We outside

# %%
marks=int(input("Enter exam marks "))
if marks>=50:
  print("Congratulations,you passed!!")
else:
  print("Unfortunately,you did not meet the exam passmark.")
# Out:
# Enter exam marks 49
# Unfortunately,you did not meet the exam passmark.

# %% [markdown]
# Password Checker

# %%
password=input("Enter password ")
if password!="python123":
  print("Access denied")
else:
  print("Access granted")
# Out:
# Enter password python123
# Access granted

# %% [markdown]
# elif

# %%
is_cloudy=input("if it is cloudy type 1,if not type 2 ")
is_raining=input("if it is raining type 1,if not type 2 ")
if is_raining=="1":
  print("use an umbrella")
elif is_cloudy=='1':
  print("carry an umbrella")
# Out:
# if it is cloudy type 1,if not type 2 1
# if it is raining type 1,if not type 2 1
# use an umbrella

# %%
grade=input("Enter your grade")
if grade == "A":
  print("you scored above 80")
elif grade == "B":
  print("you scored between 71 and 80")
elif grade == "C":
  print("you scored between 61 and 70")
elif grade == "D":
  print("you scored between 51 and 60")
elif grade == "E":
  print("you scored between 41 and 50")
elif grade == "F":
  print("you scored lower than 41")
else:
  print("the grade you entered is invalid")
# Out:
# Enter your gradeG
# the grade you entered is invalid

# %% [markdown]
# Discrete python

# %%
a=1
b=2
c=3
print(a==b and b==c)
print(a>b or c>b)
# Out:
# False
# True

# %%
value=int(input("Enter value "))
if value%3==0 and value%2 ==0:
  print("divisible by both two and three")
elif value%2==0:
  print("divisible by two")
elif value%3==0:
  print("divisible by three")
else :
  print("not divisible by both 2 and 3")
# Out:
# Enter value 7
# not divisible by both 2 and 3

# %%
_250ml=int(input("How many containers are above one litre? "))
_500ml=int(input("How many containers are above one litre? "))
_750ml=int(input("How many containers are above one litre? "))
_1l=int(input("How many containers are above one litre? "))
_2l=int(input("How many containers are above one litre? "))
_250ml=int(input("How many containers are above one litre? "))

# %% [markdown]
# It is commonly said that one human year is equivalent to 7 dog years. However this simple conversion fails to recognize that dogs reach adulthood in approximately two years. As a result, some people believe that it is better to count each of the first two human years as 10.5 dog years, and then count each additional human year as 4 dog years. Write a program that implements the conversion from human years to dog years described in the previous paragraph. Ensure that your program works correctly for conversions of less than two human years and for conversions of two or more human years. Your program should display an appropriate error message if the user enters a negative number.

# %%
age=int(input("Age of dog in human years = "))
if 2<=age:
  print(age*10.5)
elif 2>age:
  print((2*10.5)+((age-2)*4))
else:
  print("the age you entered is invalid")
# Out:
# Age of dog in human years = 4
# 42.0

# %% [markdown]
# index

# %%
word="PYTHON"
print(word[0])
print(word[1])
print(word[2])
print(word[3])
print(word[4])
print(word[5])
print(word[-1])
print(word[-2])
print(word[-3])
print(word[-4])
print(word[-5])
print(word[-6])
# Out:
# P
# Y
# T
# H
# O
# N
# N
# O
# H
# T
# Y
# P

# %% [markdown]
# Slicing

# %%
text="PYTHON"
print(text[0:2])#indices 0 1
print(text[2:])#indices 2 to end
print(text[:4])#start to 3
print(text[2:4])
# Out:
# PY
# THON
# PYTH
# TH
