# %% [markdown]
# <a href="https://colab.research.google.com/github/SamsonKinara/CDAV/blob/main/TaskDay5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
choice = input("Enter E for encoding or D for decoding: ").upper()
letter = input("Enter a letter: ").lower()
shift = 3
message = ""
while letter != "stop":
    if letter in alphabet:
        index = alphabet.index(letter)
        if choice == "E":
            new_index = (index + shift) % 26
        elif choice == "D":
            new_index = (index - shift) % 26
        else:
            print("Invalid choice!")
            break
        message += alphabet[new_index]
    elif letter == " ":
        message += " "
    else:
        print("Invalid input")
    letter = input("Enter the next letter (or type 'stop' to finish): ").lower()
if choice == "E":
    print("Encrypted message:", message)
elif choice == "D":
    print("Decoded message:", message)

# %%
word=input("Enter a word: ").lower()
left=0
right=len(word)-1
palindrome=True
while left<right:
  if word[left]!= word[right]:
    palindrome=False
    break
  left= left+1
  right= right-1
if palindrome:
  print(word,'is a palindrome')
else:
  print(word,"is not a palindrome")

# %%
n=float(input("Enter your first number: "))
m=float(input("Enter your second number: "))
d=min(m,n)
while d>0:
  if(n%d)!=0 or (m%d)!=0:
    d-=1
  else:
    print("the greatest comon divisor is",d)
    d=0
# Out:
# Enter your first number: 55
# Enter your second number: 765
# the greatest comon divisor is 5.0
