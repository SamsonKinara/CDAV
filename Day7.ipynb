# %% [markdown]
# <a href="https://colab.research.google.com/github/SamsonKinara/CDAV/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a program that reads integers from the user until a blank line is entered. Once
# all of the integers have been read your program should display all of the negative
# numbers, followed by all of the zeros, followed by all of the positive numbers. Within
# each group the numbers should be displayed in the same order that they were entered
# by the user. For example, if the user enters the values 3, -4, 1, 0, -1, 0, and -2 then
# your program should output the values -4, -1, -2, 0, 0, 3, and 1. Your program
# should display each value on its own line.

# %%
number=[]
value=""
while value!="":
  value=(input("Insert an integer or press _ to stop the program: "))
  number.append(value)
  if value=="":
    break


for num in number:
    print(num)

# %%
positives=[]
negatives=[]
zeros=[]
while True:
  val=input("Enter an integer: ")
  if val=="":
    break
  val=int(val)
  if val < 0:
    negatives.append(val)
  elif val==0:
    zeros.append(val)
  else :
    positives.append(val)
for n in negatives:
  print(n)
for z in zeros:
  print(z)
for p in positives:
  print(p)
# Out:
# Enter an integer: -3
# Enter an integer: 3
# Enter an integer: -2
# Enter an integer: 2
# Enter an integer: -1
# Enter an integer: 1
# Enter an integer: 0
# Enter an integer: 0
# Enter an integer:
# -3
# -2
# -1
# 0
# 0
# 3
# 2
# 1

# %% [markdown]
# Tuples

# %%
rgb_color=(101,200,25)
print(type(rgb_color))
print(rgb_color)
# Out:
# <class 'tuple'>
# (101, 200, 25)

# %%
pi_val=(3.14)
pi_tup=(3.14,)
print(type(pi_val))
print(type(pi_tup))
# Out:
# <class 'float'>
# <class 'tuple'>

# %%
names_tup=("john","Mary","john","peter")
print(names_tup.index("Mary"))
print(names_tup.count("john"))
# Out:
# 1
# 2

# %%
a,b=(10,11)
print(b)
# Out:
# 11

# %%
for name in names_tup:
  print(name.upper())
# Out:
# JOHN
# MARY
# JOHN
# PETER

# %%
print([name.upper()for name in names_tup])
# Out:
# ['JOHN', 'MARY', 'JOHN', 'PETER']

# %% [markdown]
# Sets

# %%
fruits=["apple","mango","apple","mango","banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'apple', 'mango', 'banana']

# %%
fruits_set={"apple","mango","apple","mango","banana"}
print(fruits_set)
# Out:
# {'mango', 'banana', 'apple'}

# %%
fruits_set2= set(fruits)
print(fruits_set2)
# Out:
# {'mango', 'banana', 'apple'}

# %%
fruits_set_upper={fruit.upper()}

# %%
fruits_set.add("kiwi")
print(fruits_set)
# Out:
# {'kiwi', 'mango', 'banana', 'apple'}

# %%
fruits_set.discard("mango")
print(fruits_set)
# Out:
# {'kiwi', 'banana', 'apple'}

# %% [markdown]
# Dictionaries

# %%
student_grades={
    "math":80,
    "English":93,
    "Cre":97
}
student_grades["math"]#to print specific key
student_grades["physics"]=99#to add to the dictionary
print(type(student_grades))
math_results=student_grades["math"]
print(math_results)
# Out:
# <class 'dict'>
# 80

# %%
student_grades["math"]=99#to change the value of a key
print(student_grades)
# Out:
# {'math': 99, 'English': 93, 'Cre': 97, 'physics': 99}

# %%
del student_grades["math"]#to delete a key

# %%
student_grades.update({"math":70,"English":52})

# %%
print(student_grades)
# Out:
# {'English': 52, 'Cre': 97, 'physics': 99, 'math': 70}

# %%
print(student_grades.get("math",0))
# Out:
# 70

# %%
del student_grades["math"]

# %%
print(student_grades.get("math","not found!"))#returns a default value when the key doesnt exist
# Out:
# not found!

# %%
student_grades.keys()
# Out:
# dict_keys(['English', 'Cre', 'physics'])

# %%
student_grades.values()
# Out:
# dict_values([52, 97, 99])

# %%
student_grades.items()
# Out:
# dict_items([('English', 52), ('Cre', 97), ('physics', 99)])

# %%
for k in student_grades.keys():
  print(k)
# Out:
# English
# Cre
# physics

# %%
for val in student_grades.values():
  print(val)
# Out:
# 52
# 97
# 99

# %%
for key,value in student_grades.items():
  print(key)
  print(value)
# Out:
# English
# 52
# Cre
# 97
# physics
# 99

# %%
for item in student_grades.items():
  print(item)
# Out:
# ('English', 52)
# ('Cre', 97)
# ('physics', 99)

# %%
for key,val in student_grades.items():
  print(key,"contains",val)
# Out:
# English contains 52
# Cre contains 97
# physics contains 99

# %%
A={1,2,3,3,4}
B={3,4,5,6}
print(A)
print(B)
print("Union:",A|B)
print("Intersecgtion:",A&B)
print("Difference:",A-B)
A.add(7)
A.remove(2)
print(A)
# Out:
# {1, 2, 3, 4}
# {3, 4, 5, 6}
# Union: {1, 2, 3, 4, 5, 6}
# Intersecgtion: {3, 4}
# Difference: {1, 2}
# {1, 3, 4, 7}

# %%
#Entering student details
students = []
more = "yes"
total = 0
while more == "yes":
    name = input("Enter student name: ")
    age = input("Enter student age: ")
    gender = input("Enter student gender: ")

    student = {
        "name": name,
        "age": age,
        "gender": gender,
    }

    students.append(student)

    more = input("Add another student? (yes/no): ")

#recording marks
marks = []
for i in range(len(students)):
  print(f"Student {i + 1} marks:")
  mark = input("Enter marks: ")
  students[i]["mark"] = mark

index=0
while index < len(students):
  print("Student", index + 1)
  print("Name:", students[index]["name"])
  print("Age:", students[index]["age"])
  print("Gender:", students[index]["gender"])
  print("Marks:", students[index]["mark"])
  print("\n")
  index = index + 1

#viewing failing scores
print("FAILING SCORES")
fail=False

for i in students:
  if int(i["mark"]) < 50:
    print(i["name"],"-",i["mark"])
    fail=True
    break

  if fail==True:
    print("No failing scores")
    print("\n")

print("Program exit")
