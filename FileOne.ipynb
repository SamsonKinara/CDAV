# %% [markdown]
# <a href="https://colab.research.google.com/github/SamsonKinara/CDAV/blob/main/FileOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SUIIII

# %%
print(10
      )
# Out:
# 10

# %%
Current_year=2026
Birth_Year=2007
Age=Current_year-Birth_Year
print (
  Age)
# Out:
# 19

# %%
print (26-7
      )
# Out:
# 19

# %%
print("my name is Kinara." )
# Out:
# my name is Kinara.

# %%
Goat="Messi"
Goat="Ronaldo"
print (Goat)
# Out:
# Ronaldo

# %%
print("my name is Kinara." )
# Out:
# my name is Kinara.

# %%
print("i am 19 years old")
# Out:
# i am 19 years old

# %%
print("my hobby is football")
# Out:
# my hobby is football

# %%
age=19
name="Kinara"
hobby="Football"
print("my name is",name)
# Out:
# my name is Kinara

# %%
print("i am",age,"years old")
# Out:
# i am 19 years old

# %%
print("my hobby is",hobby)
# Out:
# my hobby is Football

# %%
print(f"my name is {name}")
# Out:
# my name is Kinara

# %%
print(f"my hobby is {hobby}")
# Out:
# my hobby is Football

# %%
print(f"my age is {age}")
# Out:
# my age is 19

# %%
FirstName="Cole"

# %%
print(FirstName)
# Out:
# Cole

# %%
_1stName="Palmer"

# %%
print(_1stName)
# Out:
# Palmer
